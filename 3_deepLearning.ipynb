# %% [markdown]
# # Downloading Libraries

# %%
! pip install nltk
! pip install vaderSentiment
! pip install pytrends
! pip install textblob
! pip install wordcloud
! pip install gensim
! pip install seaborn
! pip install TextBlob
! pip install joblib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: nltk in c:\users\edward zavala\appdata\roaming\python\python39\site-packages (3.9.1)
# Requirement already satisfied: click in c:\users\edward zavala\appdata\roaming\python\python39\site-packages (from nltk) (8.1.8)
# Requirement already satisfied: joblib in c:\users\edward zavala\appdata\roaming\python\python39\site-packages (from nltk) (1.5.1)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\edward zavala\appdata\roaming\python\python39\site-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in c:\users\edward zavala\appdata\roaming\python\python39\site-packages (from nltk) (4.67.1)
# Requirement already satisfied: colorama in c:\users\edward zavala\appdata\roaming\python\python39\site-packages (from click->nltk) (0.4.6)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: vaderSentiment in c:\users\edward zavala\appdata\roaming\python\python39\site-packages (3.3.2)
# Requirement already satisfied: requests in c:\users\edward zavala\appdata\roaming\python\python39\site-packages (from vaderSentiment) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\edward zavala\appdata\roaming\python\python39\site-packages (from requests->vaderSentiment) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\edward zavala\appdata\roaming\python\python39\site-packages (from requests->vaderSentiment) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\edward zavala\appdata\roaming\python\python39\site-packages (from requests->vaderSentiment) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\edward zavala\appdata\roaming\python\python39\site-packages (from requests->vaderSentiment) (2025.4.26)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pytrends in c:\users\edward zavala\appdata\roaming\python\python39\site-packages (4.9.2)
# Requirement already satisfied: requests>=2.0 in c:\users\edward zavala\appdata\roaming\python\python39\site-packages (from pytrends) (2.32.3)
# Requirement already satisfied: pandas>=0.25 in c:\users\edward zavala\appdata\roaming\python\python39\site-packages (from pytrends) (2.2.3)
# Requirement already satisfied: lxml in c:\users\edward zavala\appdata\roaming\python\python39\site-packages (from pytrends) (5.4.0)
# Requirement already satisfied: numpy>=1.22.4 in c:\users\edward zavala\appdata\roaming\python\python39\site-packages (from pandas>=0.25->pytrends) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\edward zavala\appdata\roaming\python\python39\site-packages (from pandas>=0.25->pytrends) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\edward zavala\appdata\roaming\python\python39\site-packages (from pandas>=0.25->pytrends) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\edward zavala\appdata\roaming\python\python39\site-packages (from pandas>=0.25->pytrends) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\edward zavala\appdata\roaming\python\python39\site-packages (from python-dateutil>=2.8.2->pandas>=0.25->pytrends) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\edward zavala\appdata\roaming\python\python39\site-packages (from requests>=2.0->pytrends) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\edward zavala\appdata\roaming\python\python39\site-packages (from requests>=2.0->pytrends) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\edward zavala\appdata\roaming\python\python39\site-packages (from requests>=2.0->pytrends) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\edward zavala\appdata\roaming\python\python39\site-packages (from requests>=2.0->pytrends) (2025.4.26)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: textblob in c:\users\edward zavala\appdata\roaming\python\python39\site-packages (0.19.0)
# Requirement already satisfied: nltk>=3.9 in c:\users\edward zavala\appdata\roaming\python\python39\site-packages (from textblob) (3.9.1)
# Requirement already satisfied: click in c:\users\edward zavala\appdata\roaming\python\python39\site-packages (from nltk>=3.9->textblob) (8.1.8)
# Requirement already satisfied: joblib in c:\users\edward zavala\appdata\roaming\python\python39\site-packages (from nltk>=3.9->textblob) (1.5.1)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\edward zavala\appdata\roaming\python\python39\site-packages (from nltk>=3.9->textblob) (2024.11.6)
# Requirement already satisfied: tqdm in c:\users\edward zavala\appdata\roaming\python\python39\site-packages (from nltk>=3.9->textblob) (4.67.1)
# Requirement already satisfied: colorama in c:\users\edward zavala\appdata\roaming\python\python39\site-packages (from click->nltk>=3.9->textblob) (0.4.6)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: wordcloud in c:\users\edward zavala\appdata\roaming\python\python39\site-packages (1.9.4)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\edward zavala\appdata\roaming\python\python39\site-packages (from wordcloud) (1.26.4)
# Requirement already satisfied: pillow in c:\users\edward zavala\appdata\roaming\python\python39\site-packages (from wordcloud) (11.2.1)
# Requirement already satisfied: matplotlib in c:\users\edward zavala\appdata\roaming\python\python39\site-packages (from wordcloud) (3.9.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\edward zavala\appdata\roaming\python\python39\site-packages (from matplotlib->wordcloud) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\edward zavala\appdata\roaming\python\python39\site-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\edward zavala\appdata\roaming\python\python39\site-packages (from matplotlib->wordcloud) (4.58.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\edward zavala\appdata\roaming\python\python39\site-packages (from matplotlib->wordcloud) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\edward zavala\appdata\roaming\python\python39\site-packages (from matplotlib->wordcloud) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\edward zavala\appdata\roaming\python\python39\site-packages (from matplotlib->wordcloud) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\edward zavala\appdata\roaming\python\python39\site-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\edward zavala\appdata\roaming\python\python39\site-packages (from matplotlib->wordcloud) (6.5.2)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\edward zavala\appdata\roaming\python\python39\site-packages (from importlib-resources>=3.2.0->matplotlib->wordcloud) (3.22.0)
# Requirement already satisfied: six>=1.5 in c:\users\edward zavala\appdata\roaming\python\python39\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.17.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: gensim in c:\users\edward zavala\appdata\roaming\python\python39\site-packages (4.3.3)
# Requirement already satisfied: numpy<2.0,>=1.18.5 in c:\users\edward zavala\appdata\roaming\python\python39\site-packages (from gensim) (1.26.4)
# Requirement already satisfied: scipy<1.14.0,>=1.7.0 in c:\users\edward zavala\appdata\roaming\python\python39\site-packages (from gensim) (1.13.1)
# Requirement already satisfied: smart-open>=1.8.1 in c:\users\edward zavala\appdata\roaming\python\python39\site-packages (from gensim) (7.1.0)
# Requirement already satisfied: wrapt in c:\users\edward zavala\appdata\roaming\python\python39\site-packages (from smart-open>=1.8.1->gensim) (1.17.2)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: seaborn in c:\users\edward zavala\appdata\roaming\python\python39\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\edward zavala\appdata\roaming\python\python39\site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in c:\users\edward zavala\appdata\roaming\python\python39\site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\edward zavala\appdata\roaming\python\python39\site-packages (from seaborn) (3.9.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\edward zavala\appdata\roaming\python\python39\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\edward zavala\appdata\roaming\python\python39\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\edward zavala\appdata\roaming\python\python39\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.58.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\edward zavala\appdata\roaming\python\python39\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\edward zavala\appdata\roaming\python\python39\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\edward zavala\appdata\roaming\python\python39\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\edward zavala\appdata\roaming\python\python39\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\edward zavala\appdata\roaming\python\python39\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\edward zavala\appdata\roaming\python\python39\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (6.5.2)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\edward zavala\appdata\roaming\python\python39\site-packages (from importlib-resources>=3.2.0->matplotlib!=3.6.1,>=3.4->seaborn) (3.22.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\edward zavala\appdata\roaming\python\python39\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\edward zavala\appdata\roaming\python\python39\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\edward zavala\appdata\roaming\python\python39\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: TextBlob in c:\users\edward zavala\appdata\roaming\python\python39\site-packages (0.19.0)
# Requirement already satisfied: nltk>=3.9 in c:\users\edward zavala\appdata\roaming\python\python39\site-packages (from TextBlob) (3.9.1)
# Requirement already satisfied: click in c:\users\edward zavala\appdata\roaming\python\python39\site-packages (from nltk>=3.9->TextBlob) (8.1.8)
# Requirement already satisfied: joblib in c:\users\edward zavala\appdata\roaming\python\python39\site-packages (from nltk>=3.9->TextBlob) (1.5.1)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\edward zavala\appdata\roaming\python\python39\site-packages (from nltk>=3.9->TextBlob) (2024.11.6)
# Requirement already satisfied: tqdm in c:\users\edward zavala\appdata\roaming\python\python39\site-packages (from nltk>=3.9->TextBlob) (4.67.1)
# Requirement already satisfied: colorama in c:\users\edward zavala\appdata\roaming\python\python39\site-packages (from click->nltk>=3.9->TextBlob) (0.4.6)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: joblib in c:\users\edward zavala\appdata\roaming\python\python39\site-packages (1.5.1)

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split


from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping

import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
# Download NLTK resources (if not already downloaded)
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('wordnet', quiet=True)
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Edward
# [nltk_data]     Zavala\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to C:\Users\Edward
# [nltk_data]     Zavala\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to C:\Users\Edward
# [nltk_data]     Zavala\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %% [markdown]
# # Importing Dataset

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from google.colab import drive
#       2 drive.mount('/content/drive')
#
# ModuleNotFoundError: No module named 'google.colab'

# %%
df = pd.read_csv('/content/drive/MyDrive/Datasets/Cleaned Data/reviews.csv')
df.head()

# %% [markdown]
# # Date Preprocessing

# %%
df.isnull().sum()

# %%
# Dropping the null values
df.dropna(inplace=True)
df.isnull().sum()

# %% [markdown]
# ## **<center><u>Assessment: Experimentations (using Deep Learning)</u></center>**

# %%
stop_words = set(stopwords.words('english'))

def preprocess_text(text):
    # Tokenize and remove stop words
    tokens = word_tokenize(text)
    tokens = [word for word in tokens if word.isalpha()
              and word not in stop_words]
    return " ".join(tokens)

# %%
# Apply preprocessing to cleaned comments
df['processed_comments'] = df['cleaned_comments'].apply(preprocess_text)

# %%
# Tokenize text
tokenizer = Tokenizer(num_words=500, oov_token="<OOV>")
tokenizer.fit_on_texts(df['processed_comments'])
sequences = tokenizer.texts_to_sequences(df['processed_comments'])

# %%
# Pad sequences
max_length = max(len(x) for x in sequences)
padded_sequences = pad_sequences(sequences, maxlen=max_length, padding='post')

# %%
# Encode labels
labels = pd.get_dummies(df['sentiment']).values

# %%
# Split the data
X_train, X_test, y_train, y_test = train_test_split(
    padded_sequences, labels, test_size=0.2, random_state=42)

# %%
model = Sequential()
model.add(Embedding(5000, 128, input_length=max_length))
model.add(LSTM(64, dropout=0.2, recurrent_dropout=0.2))
model.add(Dense(32, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(labels.shape[1], activation='softmax'))

model.compile(loss='categorical_crossentropy',
              optimizer='adam', metrics=['accuracy'])
model.summary()

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=3, verbose=1)

history = model.fit(X_train, y_train, epochs=100, batch_size=128,
                    validation_split=0.2, callbacks=[early_stopping])

# %%
loss, accuracy = model.evaluate(X_test, y_test)
print(f"Test Accuracy: {accuracy * 100}%")
